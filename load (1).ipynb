# %%
''' Copyright [2024] [vandermi silva SWPERF project]

Licensed under the Apache License, Version 2.0 (the "License");
you may not use this file except in compliance with the License.
You may obtain a copy of the License at
http://www.apache.org/licenses/LICENSE-2.0

Unless required by applicable law or agreed to in writing, software
distributed under the License is distributed on an "AS IS" BASIS,
WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
See the License for the specific language governing permissions and
limitations under the License.'''

# Python Script used to load the cvs file and create a new data frame using Pandas
# in this example we using the dataset called df_anonymizedManaus.csv
# Some experiments are demostrate we can generate some graphics for get some insigths 
# about  the dataset organization.
# The script is a part of the project Swperf sub group Inteligent Hardware (IH)
# Author: Vandermi Silva
# 
# Federal University of Amazonas
# ICET and ICOMP UFAM
# e-mail : vandermi@ufam.edu.br

import pandas as pd # type: ignore

filepath = "df_anonymizedManaus.csv"
dataFrame = pd.read_csv(filepath) 
dataFrame.head
display(dataFrame)
# Out:
#         Model    Current Date Time iso  Location Status  Latitude  Longitude  \
# 0           1  2023-08-21 12:55:21  BR             True  -3.04213   -60.0062
# 1           1  2023-12-07 20:08:42  BR             True  -3.06602   -60.0131
# 2           1  2023-12-04 10:06:18  BR             True  -3.04272   -60.0071
# 3           1  2023-10-06 05:44:01  BR             True  -3.04263   -60.0071
# 4           1  2023-10-06 06:16:46  BR             True  -3.04263   -60.0071
# ...       ...                  ...  ..              ...       ...        ...
# 526195      6  2024-02-06 13:10:04  BR             True  -3.08826   -59.9648
# 526196      6  2024-02-06 13:24:55  BR             True  -3.08837   -59.9648
# 526197      6  2024-02-06 09:35:35  BR             True  -3.08969   -59.9879
# 526198      6  2024-02-06 10:39:04  BR             True  -3.08783   -59.9644
# 526199      6  2024-02-06 12:54:29  BR             True  -3.08832   -59.9649
#
# ...

# %%
# identify and remove empty values if exist
dataFrame = dataFrame.dropna()
display(dataFrame.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 526200 entries, 0 to 526199
# Data columns (total 33 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Model                 526200 non-null  int64
#  1   Current Date Time     526200 non-null  object
#  2   iso                   526200 non-null  object
#  3   Location Status       526200 non-null  bool
#  4   Latitude              526200 non-null  float64
#  5   Longitude             526200 non-null  float64
#  6   Mobile Status         526200 non-null  bool
#  7   Network Operator      526200 non-null  int64
#  8   Network Type          526200 non-null  object
#  9   dBm                   526200 non-null  float64
#  10  RSSI LTE              526200 non-null  float64
#  11  RSRP LTE              526200 non-null  float64
#  12  RSRQ LTE              526200 non-null  float64
#  13  SNR LTE               526200 non-null  float64
# ...
