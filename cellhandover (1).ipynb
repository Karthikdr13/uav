# %%
# this is a example data set where i took few rows and column from the real data set to run since the real data set 
# was very large and took more time to process

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN
import numpy as np

# Load data
df = pd.read_csv("Book1.csv")

# Parse datetime
df['Current Date Time'] = pd.to_datetime(df['Current Date Time'])

# Optional: filter out invalid GPS or signal data
df = df[(df['Latitude'].notnull()) & (df['Longitude'].notnull())]
df = df[(df['RSRP LTE'].notnull()) & (df['CI LTE'].notnull())]

# Create a features dataframe for user fingerprinting
features = df[['Latitude', 'Longitude', 'RSRP LTE', 'CI LTE', 'TAC LTE', 'PCI LTE', 'EARFCN', 'Chip Operator']]

# Normalize the features
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# DBSCAN clustering to estimate users
dbscan = DBSCAN(eps=0.5, min_samples=10)  # Tune eps if needed
clusters = dbscan.fit_predict(features_scaled)

# Assign cluster labels back to the DataFrame
df['user_cluster'] = clusters

# Count unique users (excluding noise labeled as -1)
num_users = df[df['user_cluster'] != -1]['user_cluster'].nunique()
print(f"Estimated number of unique users: {num_users}")
# Out:
# Estimated number of unique users: 2
# C:\Users\karth\AppData\Local\Temp\ipykernel_2700\1188373181.py:10: UserWarning: Parsing dates in %d-%m-%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Current Date Time'] = pd.to_datetime(df['Current Date Time'])

# %%
# Sort data by time
df = df.sort_values(['user_cluster', 'Current Date Time'])

# Detect transitions
df['prev_CI'] = df.groupby('user_cluster')['CI LTE'].shift(1)
df['cell_changed'] = df['CI LTE'] != df['prev_CI']

# Count handovers per user
handover_counts = df[df['cell_changed'] & (df['user_cluster'] != -1)].groupby('user_cluster').size()
print(f"Average handovers per user: {handover_counts.mean():.2f}")
print(f"Total number of cell transitions (all users): {handover_counts.sum()}")
# Out:
# Average handovers per user: 3.00
# Total number of cell transitions (all users): 6

# %%
import pandas as pd
import folium
from folium.plugins import AntPath
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN
from IPython.display import display

# Load and clean data
df = pd.read_csv("Book1.csv")
df['Current Date Time'] = pd.to_datetime(df['Current Date Time'])
df = df.dropna(subset=['Latitude', 'Longitude', 'CI LTE', 'PCI LTE'])

# Step 1: Cluster users by location
location_features = df[['Latitude', 'Longitude']]
location_scaled = StandardScaler().fit_transform(location_features)
df['user_cluster'] = DBSCAN(eps=0.3, min_samples=10).fit_predict(location_scaled)

# Step 2: Get all valid users (clusters not labeled as -1)
valid_clusters = df[df['user_cluster'] != -1]['user_cluster'].unique()

# Step 3: Loop over each user and visualize
for user_id in valid_clusters[:3]:  # Limit to first 3 users for clarity — adjust as needed
    user_df = df[df['user_cluster'] == user_id].copy().sort_values('Current Date Time')
    
    # Detect handover types
    user_df['prev_CI'] = user_df['CI LTE'].shift(1)
    user_df['prev_PCI'] = user_df['PCI LTE'].shift(1)
    
    def classify_handover(row):
        if pd.isna(row['prev_CI']) or pd.isna(row['prev_PCI']):
            return None
        if row['CI LTE'] != row['prev_CI']:
            return "inter-cell"
        elif row['PCI LTE'] != row['prev_PCI']:
            return "intra-cell"
        else:
            return None

    user_df['handover_type'] = user_df.apply(classify_handover, axis=1)

    # Initialize map
    start_coords = [user_df.iloc[0]['Latitude'], user_df.iloc[0]['Longitude']]
    m = folium.Map(location=start_coords, zoom_start=13)
    
    # Movement path
    path_coords = list(zip(user_df['Latitude'], user_df['Longitude']))
    AntPath(path_coords, color='blue', weight=4, delay=800).add_to(m)

    # Handover markers
    for _, row in user_df[user_df['handover_type'].notnull()].iterrows():
        ho_type = row['handover_type']
        icon_color = 'orange' if ho_type == 'intra-cell' else 'red'
        folium.Marker(
            location=[row['Latitude'], row['Longitude']],
            popup=f"{ho_type} handover\n{row['Current Date Time']}",
            icon=folium.Icon(color=icon_color, icon='signal')
        ).add_to(m)

    # Start & End markers
    folium.Marker(
        location=start_coords,
        popup=f"User {user_id} Start",
        icon=folium.Icon(color='green', icon='play')
    ).add_to(m)

    end_coords = [user_df.iloc[-1]['Latitude'], user_df.iloc[-1]['Longitude']]
    folium.Marker(
        location=end_coords,
        popup="End",
        icon=folium.Icon(color='purple', icon='stop')
    ).add_to(m)

    # Display map
    print(f"Map for User {user_id}")
    display(m)
# Out:
# C:\Users\karth\AppData\Local\Temp\ipykernel_23428\655259091.py:10: UserWarning: Parsing dates in %d-%m-%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Current Date Time'] = pd.to_datetime(df['Current Date Time'])
# Map for User 0
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_faa1f6e2a44e897dbd70c0b3241e463c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-ant-path@1.1.2/dist/leaflet-ant-path.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_faa1f6e2a44e897dbd70c0b3241e463c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_faa1f6e2a44e897dbd70c0b3241e463c = L.map(
#                 &quot;map_faa1f6e2a44e897dbd70c0b3241e463c&quot;,
#                 {
#                     center: [-3.04207, -60.0061],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_742d783cb0349db6ea394a40aa0dc1e1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_742d783cb0349db6ea394a40aa0dc1e1.addTo(map_faa1f6e2a44e897dbd70c0b3241e463c);
#
#
#             ant_path_f14cd84b840dfed9bb7d9d7923f20f24 = L.polyline.antPath(
#               [[-3.04207, -60.0061], [-3.04207, -60.0061], [-3.04207, -60.0061], [-3.07992, -60.0022], [-3.04825, -60.0058], [-3.04213, -60.0062], [-3.04288, -60.0035], [-3.08839, -59.9651], [-3.07925, -60.0015], [-3.07928, -60.0014], [-3.13487, -60.0165], [-3.0427, -60.0061], [-3.04263, -60.0071], [-3.04263, -60.0071], [-3.04263, -60.0071], [-3.04263, -60.0071], [-3.04263, -60.0071], [-3.04261, -60.0071], [-3.04264, -60.0071], [-3.04264, -60.0071], [-3.04265, -60.0071], [-3.04265, -60.0071], [-3.08837, -59.9648], [-3.06589, -60.0116], [-3.04272, -60.0071], [-3.0958, -59.9854], [-3.06602, -60.0131], [-3.04264, -60.0071], [-3.12559, -60.0226], [-3.04243, -60.0069], [-3.04832, -59.9978], [-3.04991, -59.9925], [-3.06009, -59.9913], [-3.06055, -59.9912], [-3.06137, -59.9885], [-3.08833, -59.9649], [-3.08837, -59.9649], [-3.08833, -59.9649], [-3.0882, -59.9645], [-3.08806, -59.9633], [-3.08879, -59.9636], [-3.08882, -59.9637], [-3.08882, -59.9638], [-3.08907, -59.9649], [-3.08896, -59.9649], [-3.08848, -59.9648], [-3.08846, -59.9648], [-3.08857, -59.9648], [-3.08839, -59.9648], [-3.08836, -59.9649], [-3.08906, -59.9634], [-3.08882, -59.9649], [-3.08857, -59.9647], [-3.08997, -59.9622], [-3.09198, -59.9638], [-3.09253, -59.9633], [-3.09183, -59.9638], [-3.09991, -59.9747], [-3.04549, -60.0156], [-3.04269, -60.0071], [-3.04269, -60.0071], [-3.04279, -60.0071], [-3.04279, -60.0071], [-3.04261, -60.0071], [-3.04268, -60.0071], [-3.04265, -60.0071], [-3.1264, -60.0206], [-3.00829, -60.0431], [-3.0879, -60.0267], [-3.10836, -60.0267], [-3.1298, -60.0269], [-3.11813, -60.0252], [-3.11043, -60.0344], [-3.10804, -60.0358], [-3.10767, -60.0361], [-3.09207, -60.0528], [-3.08699, -60.0626], [-3.06428, -60.0601], [-3.06065, -60.0629], [-3.0606, -60.0629], [-3.06065, -60.0629], [-3.06064, -60.0629], [-3.06063, -60.0629], [-3.06065, -60.0629], [-3.06063, -60.0629], [-3.06066, -60.0629], [-3.06068, -60.0629], [-3.06068, -60.0629], [-3.06066, -60.0629], [-3.06067, -60.0629], [-3.06067, -60.0629], [-3.06071, -60.0629], [-3.06069, -60.0629], [-3.06069, -60.0629], [-3.06069, -60.0628], [-3.06067, -60.0629], [-3.06071, -60.0629], [-3.06067, -60.0629], [-3.04262, -60.0071], [-3.06585, -60.0034], [-3.0375, -60.0241], [-3.02412, -60.0222], [-2.93023, -60.0056], [-2.88242, -59.9523]],
#               {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;blue&quot;,
#   &quot;weight&quot;: 4,
#   &quot;opacity&quot;: 0.5,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: [
# 10,
# 20,
# ],
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: false,
#   &quot;fillColor&quot;: &quot;blue&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;smoothFactor&quot;: 1.0,
#   &quot;noClip&quot;: false,
#   &quot;paused&quot;: false,
#   &quot;reverse&quot;: false,
#   &quot;hardwareAcceleration&quot;: false,
#   &quot;delay&quot;: 800,
#   &quot;pulseColor&quot;: &quot;#FFFFFF&quot;,
# }
#         ).addTo(map_faa1f6e2a44e897dbd70c0b3241e463c);
#
#
#             var marker_5088c430a3568451c61124f316e879c2 = L.marker(
#                 [-3.07992, -60.0022],
#                 {
# }
#             ).addTo(map_faa1f6e2a44e897dbd70c0b3241e463c);
#
#
#             var icon_6156e5e83ea21248522a7bd714dffc82 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;signal&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_30d53ed3f80b20c28e2
# Map for User 1
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4fe86590a790f92fce9d5b5442aa40e7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-ant-path@1.1.2/dist/leaflet-ant-path.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4fe86590a790f92fce9d5b5442aa40e7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4fe86590a790f92fce9d5b5442aa40e7 = L.map(
#                 &quot;map_4fe86590a790f92fce9d5b5442aa40e7&quot;,
#                 {
#                     center: [-3.04208, -60006.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e2618464e66af57782a245093ef5a1de = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e2618464e66af57782a245093ef5a1de.addTo(map_4fe86590a790f92fce9d5b5442aa40e7);
#
#
#             ant_path_ec7b2b2c80e99b073a3f06253b088330 = L.polyline.antPath(
#               [[-3.04208, -60006.0], [-3.04255, -60007.0], [-3.0426, -60007.0], [-3.0426, -60007.0], [-3.09519, -60051.0], [-3.04261, -60007.0], [-3.08834, -59965.0], [-3.09015, -59966.0], [-3.08909, -59965.0], [-3.13406, -60013.0], [-3.12982, -60027.0], [-3.04262, -60007.0]],
#               {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;blue&quot;,
#   &quot;weight&quot;: 4,
#   &quot;opacity&quot;: 0.5,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: [
# 10,
# 20,
# ],
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: false,
#   &quot;fillColor&quot;: &quot;blue&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;smoothFactor&quot;: 1.0,
#   &quot;noClip&quot;: false,
#   &quot;paused&quot;: false,
#   &quot;reverse&quot;: false,
#   &quot;hardwareAcceleration&quot;: false,
#   &quot;delay&quot;: 800,
#   &quot;pulseColor&quot;: &quot;#FFFFFF&quot;,
# }
#         ).addTo(map_4fe86590a790f92fce9d5b5442aa40e7);
#
#
#             var marker_25e3a411519002e841c7aa2137045e0e = L.marker(
#                 [-3.04255, -60007.0],
#                 {
# }
#             ).addTo(map_4fe86590a790f92fce9d5b5442aa40e7);
#
#
#             var icon_f39b568d70bf9cf9af98c2bc457a0689 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;signal&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_2d4eddb225e36fe25d3b1a3bd9d67a2b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e0e2709b266dbbcb731af1c6400c160 = $(`&lt;div id=&quot;html_9e0e2709b266dbbcb731af1c6400c160&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;inter-cell handover 2023-10-07 01:00:00&lt;/div&gt;`)[0];
#                 popup_2d4eddb225e36fe25d3b1a3bd9d67a2b.setContent(html_9e0e2709b266dbbcb731af1c6400c160);
#
#
#
#         marker_25e3a411519002e841c7aa2137045e0e.bindPopup(popup_2d4eddb225e36fe25d3b1a3bd9d67a2b)
#         ;
#
#
#
#
#                 marker_25e3a411519002e841c7aa2137045e0e.setIcon(icon_f39b568d70bf9cf9af98c2bc457a0689);
#
#
#             var marker_5b7093bda59fe831da9f14773062dc05 = L.marker(
#                 [-3.0426, -60007.0],
#                 {
# }
#             ).addTo(map_4fe86590a790f92fce9d5b5442aa40e7);
#
#
#             var icon_5e7ac19f80679538e337208518a264cd = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;signal&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_08fcc041f364b8967101f8a4ffe16c6d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_72f9af52b20086f97794bb3f812355dd = $(`&lt;div id=&quot;html_72f9af52b20086f97794bb3f812355dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;inter-cell handover 2023-10-07 01:18:00&lt;/div&gt;`)[0];
#                 popup_08fcc041f364b8967101f8a4ffe16c6d.setContent(html_72f9af52b20086f97794bb3f812355dd);
#
#
#
#         marker_5b7093bda59fe831da9f14773062dc05.bindPopup(popup_08fcc041f364b8967101f8a4ffe16c6d)
#         ;
#
#
#
#
#                 marker_5b7093bda59fe831da9f14773062dc05.setIcon(icon_5e7ac19f80679538e337208518a264cd);
#
#
#             v

# %%
import pandas as pd
import folium
from folium.plugins import AntPath #Animates movement 
from sklearn.preprocessing import StandardScaler#Normalizes GPS coordinates before clustering.
from sklearn.cluster import DBSCAN #clustering algorithm to find user groups based on location
from IPython.display import display

    # Load and clean data
df = pd.read_csv("Book1.csv")
df['Current Date Time'] = pd.to_datetime(df['Current Date Time'])
df = df.dropna(subset=['Latitude', 'Longitude', 'CI LTE', 'PCI LTE', 'RSRP LTE', 'CQI LTE', 'SNR LTE'])

    # Step 1: Cluster users based on location
location_scaled = StandardScaler().fit_transform(df[['Latitude', 'Longitude']])
    #(normalizing lat n long)Rescale the values so that they are centered around 0 and have a consistent scale.
df['user_cluster'] = DBSCAN(eps=0.3, min_samples=10).fit_predict(location_scaled)
    # include all nearby points that are 0.3 units away in normalized coordinate space, eps = epsilon

    # Step 2: Analyze handovers per user
valid_clusters = df[df['user_cluster'] != -1]['user_cluster'].unique()

for user_id in valid_clusters[:3]:# analyze the first 3 users only, for performance
    user_df = df[df['user_cluster'] == user_id].copy().sort_values('Current Date Time')
    #work only on this users data and sort by time to track movement

    # Detect handovers
    user_df['prev_CI'] = user_df['CI LTE'].shift(1)
    user_df['prev_PCI'] = user_df['PCI LTE'].shift(1)

    def classify_handover(row):
        if pd.isna(row['prev_CI']) or pd.isna(row['prev_PCI']):
            return None
        if row['CI LTE'] != row['prev_CI']:
            return "inter-cell"
        elif row['PCI LTE'] != row['prev_PCI']:
            return "intra-cell"
        return None

    user_df['handover_type'] = user_df.apply(classify_handover, axis=1)

    #  calcuation of  handover
    def infer_reason(row):
        rsrp = row['RSRP LTE']
        cqi = row['CQI LTE']
        snr = row['SNR LTE']
        reasons = []
        if rsrp < -110:
            reasons.append("Low RSRP")
        if cqi < 5:
            reasons.append("Low CQI")
        if snr < 0:
            reasons.append("Low SNR")
        return ', '.join(reasons) if reasons else "Normal signal fluctuation"

    user_df['handover_reason'] = user_df.apply(
        lambda row: infer_reason(row) if pd.notnull(row['handover_type']) else None, axis=1
    )

    # Summary printout
    ho_summary = user_df['handover_type'].value_counts()
    inter_count = ho_summary.get("inter-cell", 0)
    intra_count = ho_summary.get("intra-cell", 0)
    total = inter_count + intra_count

    print(f"\n User {user_id + 1}")
    print(f" Total Handovers: {total}")
    print(f" Inter-cell: {inter_count}")
    print(f" Intra-cell: {intra_count}")
    print(" Handover Diagnostics:")

    for _, row in user_df[user_df['handover_type'].notnull()].iterrows():
        lat, lon = row['Latitude'], row['Longitude']
        ho_type = row['handover_type']
        time = row['Current Date Time']
        reason = row['handover_reason']
        if ho_type == "inter-cell":
            explanation = f"CI LTE changed from {row['prev_CI']} to {row['CI LTE']}"
        else:
            explanation = f"PCI LTE changed from {row['prev_PCI']} to {row['PCI LTE']} (CI LTE unchanged)"
        print(f"• {ho_type.upper()} @ ({lat:.5f}, {lon:.5f}) at {time}")
        print(f"   ↪ {explanation}")
        print(f"   ⚠ Likely Reason: {reason}")

    # Step 3: Map Visualization
    start_coords = [user_df.iloc[0]['Latitude'], user_df.iloc[0]['Longitude']]
    m = folium.Map(location=start_coords, zoom_start=13)

    path_coords = list(zip(user_df['Latitude'], user_df['Longitude']))
    AntPath(path_coords, color='blue', weight=4, delay=800).add_to(m)#nimated path connecting all GPS points.

    # Add handover markers with reason in popup
    for _, row in user_df[user_df['handover_type'].notnull()].iterrows():
        ho_type = row['handover_type']
        icon_color = 'red' if ho_type == 'inter-cell' else 'orange'
        folium.Marker(
            location=[row['Latitude'], row['Longitude']],
            popup=(f"{ho_type.upper()} Handover<br>"
                   f"Time: {row['Current Date Time']}<br>"
                   f"CI: {row['CI LTE']} | PCI: {row['PCI LTE']}<br>"
                   f"Reason: {row['handover_reason']}"),
            icon=folium.Icon(color=icon_color, icon='signal')
        ).add_to(m)

    # Start and end
    folium.Marker(
        location=start_coords,
        popup=f"User {user_id} Start",
        icon=folium.Icon(color='green', icon='play')
    ).add_to(m)

    end_coords = [user_df.iloc[-1]['Latitude'], user_df.iloc[-1]['Longitude']]
    folium.Marker(
        location=end_coords,
        popup="End",
        icon=folium.Icon(color='purple', icon='stop')
    ).add_to(m)

    display(m)
# Out:
# C:\Users\karth\AppData\Local\Temp\ipykernel_31560\290744961.py:10: UserWarning: Parsing dates in %d-%m-%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Current Date Time'] = pd.to_datetime(df['Current Date Time'])
#  User 1
#  Total Handovers: 62
#  Inter-cell: 61
#  Intra-cell: 1
#  Handover Diagnostics:
# • INTER-CELL @ (-3.07992, -60.00220) at 2023-08-21 09:48:00
#    ↪ CI LTE changed from 235544839.0 to 235780357
#    ⚠ Likely Reason: Normal signal fluctuation
# • INTER-CELL @ (-3.04825, -60.00580) at 2023-08-21 11:54:00
#    ↪ CI LTE changed from 235780357.0 to 235544862
#    ⚠ Likely Reason: Normal signal fluctuation
# • INTER-CELL @ (-3.04213, -60.00620) at 2023-08-21 12:55:00
#    ↪ CI LTE changed from 235544862.0 to 235544861
#    ⚠ Likely Reason: Low SNR
# • INTER-CELL @ (-3.08839, -59.96510) at 2023-08-21 17:58:00
#    ↪ CI LTE changed from 235544861.0 to 236666642
#    ⚠ Likely Reason: Normal signal fluctuation
# • INTER-CELL @ (-3.07925, -60.00150) at 2023-08-21 22:51:00
#    ↪ CI LTE changed from 236666642.0 to 235575071
#    ⚠ Likely Reason: Low SNR
# • INTER-CELL @ (-3.13487, -60.01650) at 2023-10-02 15:17:00
#    ↪ CI LTE changed from 235575071.0 to 82310451
#    ⚠ Likely Reason: Low SNR
# • INTER-CELL @ (-3.04270, -60.00610) at 2023-10-03 19:11:00
#    ↪ CI LTE changed from 82310451.0 to 82319627
#    ⚠ Likely Reason: Normal signal fluctuation
# • INTER-CELL @ (-3.04263, -60.00710) at 2023-10-06 04:29:00
#    ↪ CI LTE changed from 82319627.0 to 235603991
#    ⚠ Likely Reason: Normal signal fluctuation
# • INTER-CELL @ (-3.04261, -60.00710) at 2023-10-06 11:13:00
#    ↪ CI LTE changed from 235603991.0 to 235544833
#    ⚠ Likely Reason: Normal signal fluctuation
# • INTER-CELL @ (-3.04264, -60.00710) at 2023-11-22 01:58:00
#    ↪ CI LTE changed from 235544833.0 to 82319627
#    ⚠ Likely Reason: Normal signal fluctuation
# • INTER-CELL @ (-3.08837, -59.96480) at 2023-11-30 17:57:00
#    ↪ CI LTE changed from 82319627.0 to 82314754
#    ⚠ Likely Reason: Normal signal fluctuation
# • INTER-CELL @ (-3.06589, -60.01160) at 2023-11-30 20:33:00
#    ↪ CI LTE changed from 82314754.0 to 82390530
#    ⚠ Likely Reason: Low SNR
# • INTER-CELL @ (-3.04272, -60.00710) at 2023-12-04 10:06:00
#    ↪ CI LTE changed from 82390530.0 to 235603991
#    ⚠ Likely Reason: Normal signal fluctuation
# • INTER-CELL @ (-3.09580, -59.98540) at 2023-12-07 18:31:00
#    ↪ CI LTE changed from 235603991.0 to 236158494
#    ⚠ Likely Reason: Normal signal fluctuation
# • INTER-CELL @ (-3.06602, -60.01310) at 2023-12-07 20:08:00
#    ↪ CI LTE changed from 236158494.0 to 235576350
#    ⚠ Likely Reason: Low SNR
# • INTER-CELL @ (-3.04264, -60.00710) at 2023-12-12 07:17:00
#    ↪ CI LTE changed from 235576350.0 to 235603991
#    ⚠ Likely Reason: Normal signal fluctuation
# • INTER-CELL @ (-3.12559, -60.02260) at 2023-12-23 09:44:00
#    ↪ CI LTE changed from 235603991.0 to 235776798
#    ⚠ Likely Reason: Normal signal fluctuation
# • INTER-CELL @ (-3.04243, -60.00690) at 2024-02-06 09:01:00
#    ↪ CI LTE changed from 235776798.0 to 82389251
#    ⚠ Likely Reason: Low SNR
# • INTER-CELL @ (-3.04832, -59.99780) at 2024-02-06 09:08:00
#    ↪ CI LTE changed from 82389251.0 to 82295042
#    ⚠ Likely Reason: Normal signal fluctuation
# • INTER-CELL @ (-3.04991, -59.99250) at 2024-02-06 09:12:00
#    ↪ CI LTE changed from 82295042.0 to 82308353
#    ⚠ Likely Reason: Normal signal fluctuation
# • INTER-CELL @ (-3.06009, -59.99130) at 2024-02-06 09:20:00
#    ↪ CI LTE changed from 82308353.0 to 82356483
#    ⚠ Likely Reason: Low SNR
# • INTER-CELL @ (-3.06055, -59.99120) at 2024-02-06 09:21:00
#    ↪ CI LTE changed from 82356483.0 to 82356227
#    ⚠ Likely Reason: Normal signal fluctuation
# • INTER-CELL @ (-3.06137, -59.98850) at 2024-02-06 09:22:00
#    ↪ CI LTE changed from 82356227.0 to 235575069
#    ⚠ Likely Reason: Low SNR
# • INTER-CELL @ (-3.08833, -59.96490) at 2024-02-06 10:06:00
#    ↪ CI LTE changed from 235575069.0 to 82314804
#    ⚠ Likely Reason: Normal signal fluctuation
# • INTER-CELL @ (-3.08837, -59.96490) at 2024-02-06 10:32:00
#    ↪ CI LTE changed from 82314804.0 to 82314764
#    ⚠ Likely Reason: Normal signal fluctuation
# • INTER-CELL @ (-3.08833, -59.96490) at 2024-02-06 10:34:00
#    ↪ CI LTE changed from 82314764.0 to 82419252
#    ⚠ Likely Reason: Low SNR
# • INTER-CELL @ (-3.08820, -59.96450) at 2024-02-06 10:37:00
#    ↪ CI LTE changed from 82419252.0 to 82314764
#    ⚠ Likely Reason: Low RSRP, Low SNR
# • INTER-CELL @ (-3.08848, -59.96480) at 2024-02-06 12:04:00
#    ↪ CI LTE changed from 82314764.0 to 82314774
#    ⚠ Likely Reason: Normal signal fluctuation
# • INTER-CELL @ (-3.08906, -59.96340) at 2024-02-06 13:40:00
#    ↪ CI LTE changed from 82314774.0 to 82314764
#    ⚠ Likely Reason: Low RSRP, Low SNR
# • INTER-CELL @ (-3.08882, -59.96490) at 2024-02-06 13:49:00
#    ↪ CI LTE changed from 82314764.0 to 82314804
#    ⚠ Likely Reason: Low RSRP, Low SNR
# • INTER-CELL @ (-3.08857, -59.96470) at 2024-02-06 13:58:00
#    ↪ CI LTE changed from 82314804.0 to 82314764
#    ⚠ Likely Reason: Normal signal fluctuation
# • INTER-CELL @ (-3.08997, -59.96220) at 2024-02-06 14:07:00
#    ↪ CI LTE changed from 82314764.0 to 235581958
#    ⚠ Likely Reason: Low RSRP, Low CQI, Low SNR
# • INTER-CELL @ (-3.09198, -59.96380) at 2024-02-06 14:14:00
#    ↪ CI LTE changed from 235581958.0 to 82319413
#    ⚠ Likely Reason: Low CQI, Low SNR
# • INTER-CELL @ (-3.09253, -59.96330) at 2024-02-06 14:14:00
#    ↪ CI LTE changed from 82319413.0 to 82328371
#    ⚠ Likely Reason: Low RSRP, Low CQI, Low SNR
# • INTER-CELL @ (-3.09183, -59.96380) at 2024-02-06 14:15:00
#    ↪ CI LTE changed from 82328371.0 to 82384181
#    ⚠ Likely Reason: Low RSRP, Low CQI, Low SNR
# • INTER-CELL @ (-3.09991, -59.97470) at 2024-02-06 14:58:00
#    ↪ CI LTE changed from 82384181.0 to 82390068
#    ⚠ Likely Reason: Low RSRP, Low CQI, Low SNR
# • INTER-CELL @ (-3.04549, -60.01560) at 2024-03-12 08:45:00
#    ↪ CI LTE changed from 82390068.0 to 235552798
#    ⚠ Likely Reason: Low SNR
# • INTER-CELL @ (-3.04269, -60.00710) at 2024-03-12 13:06:00
#    ↪ CI LTE changed from 235552798.0 to 235603994
#    ⚠ Likely Reason: Normal signal fluctuation
# • INTER-CELL @ (-3.04279, -60.00710) at 2024-03-13 06:58:00
#    ↪ CI LTE changed from 235603994.0 to 235544833
#    ⚠ Likely Reason: Normal signal fluctuation
# • INTER-CELL @ (-3.04279, -60.00710) at 2024-03-13 08:02:00
#    ↪ CI LTE changed from 235544833.0 to 235603994
#    ⚠ Likely Reason: Normal signal fluctuation
# • INTER-CELL @ (-3.04268, -60.00710) at 2024-03-23 09:47:00
#    ↪ CI LTE changed from 235603994.0 to 82319627
#    ⚠ Likely Reason: Low SNR
# • INTER-CELL @ (-3.04265, -60.00710) at 2024-03-26 12:57:00
#    ↪ CI LTE changed from 82319627.0 to 82319669
#    ⚠ Likely Reason: Low SNR
# • INTER-CELL @ (-3.12640, -60.02060) at 2024-04-01 16:16:00
#    ↪ CI LTE changed from 82319669.0 to 82298371
#    ⚠ Likely Reason: Low SNR
# • INTER-CELL @ (-3.00829, -60.04310) at 2024-04-11 11:07:00
#    ↪ CI LTE changed from 82298371.0 to 235571230
#    ⚠ Likely Reason: Low RSRP, Low SNR
# • INTER-CELL @ (-3.08790, -60.02670) at 2024-04-11 11:35:00
#    ↪ CI LTE changed from 235571230.0 to 236289821
#    ⚠ Likely Reason: Normal signal fluctuation
# • INTER-CELL @ (-3.10836, -60.02670) at 2024-04-11 11:39:00
#    ↪ CI LTE changed from 236289821.0 to 236264454
#    ⚠ Likely Reason: Low SNR
# • INTER-CELL @ (-3.12980, -60.02690) at 2024-04-11 11:50:00
#    ↪ CI LTE changed from 236264454.0 to 235777311
#    ⚠ Likely Reason: Normal signal fluctuation
# • INTER-CELL @ (-3.11813, -60.02520) at 2024-04-11 12:32:00
#    ↪ CI LTE changed from 235777311.0 to 235776769
#    ⚠ Likely Reason: Normal signal fluctuation
# • INTER-CELL @ (-3.11043, -60.03440) at 2024-04-11 12:36:00
#    ↪ CI LTE changed from 235776769.0 to 235781380
#    ⚠ Likely Reason: Low SNR
# • INTRA-CELL @ (-3.10804, -60.03580) at 2024-04-11 12:37:00
#    ↪ PCI LTE changed from 264.0 to 266 (CI LTE unchanged)
#    ⚠ Likely Reason: Normal signal fluctuation
# • INTER-CELL @ (-3.09207, -60.05280) at 2024-04-11 12:43:00
#    ↪ CI LTE changed from 235781380.0 to 235787538
#    ⚠ Likely Reason: Low SNR
# • INTER-CELL @ (-3.08699, -60.06260) at 2024-04-11 13:05:00
#    ↪ CI LTE changed from 235787538.0 to 235579649
#    ⚠ Likely Reason: Normal signal fluctuation
# • INTER-CELL @ (-3.06428, -60.06010) at 2024-04-11 13:18:00
#    ↪ CI LTE changed from 235579649.0 to 236289537
#    ⚠ Likely Reason: Normal signal fluctuation
# • INTER-CELL @ (-3.06065, -60.06290) at 2024-04-11 13:30:00
#    ↪ CI LTE changed from 236289537.0 to 236006402
#    ⚠ Likely Reason: Normal signal fluctuation
# • INTER-CELL @ (-3.06060, -60.06290) at 2024-04-11 13:59:00
#    ↪ CI LTE changed from 236006402.0 to 236006403
#    ⚠ Likely Reason: Low SNR
# • INTER-CELL @ (-3.06063, -60.06290) at 2024-04-11 14:17:00
#    ↪ CI LTE changed from 236006403.0 to 236006402
#    ⚠ Likely Reason: Normal signal fluctuation
# • INTER-CELL @ (-3.04262, -60.00710) at 2024-04-15 13:22:00
#    ↪ CI LTE changed from 236006402.0 to 82319627
#    ⚠ Likely Reason: Normal signal fluctuation
# • INTER-CELL @ (-3.06585, -60.00340) at 2024-04-15 19:24:00
#    ↪ CI LTE changed from 82319627.0 to 82390530
#    ⚠ Likely Reason: Low RSRP
# • INTER-CELL @ (-3.03750, -60.02410) at 2024-04-22 20:09:00
#    ↪ CI LTE changed from 82390530.0 to 235552771
#    ⚠ Likely Reason: Normal signal fluctuation
# • INTER-CELL @ (-3.02412, -60.02220) at 2024-04-22 20:11:00
#    ↪ CI LTE changed from 235552771.0 to 236812573
#    ⚠ Likely Reason: Low SNR
# • INTER-CELL @ (-2.93023, -60.00560) at 2024-04-22 20:24:00
#    ↪ CI LTE changed from 236812573.0 to 235792647
#    ⚠ Likely Reason: Normal signal fluctuation
# • INTER-CELL @ (-2.88242, -59.95230) at 2024-04-22 20:33:00
#    ↪ CI LTE changed from 235792647.0 to 236007442
#    ⚠ Likely Reason: Normal signal fluctuation
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c9f492ebd6aca582cb8eeb6e3e7a2298 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-ant-path@1.1.2/dist/leaflet-ant-path.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c9f492ebd6aca582cb8eeb6e3e7a2298&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c9f492ebd6aca582cb8eeb6e3e7a2298 = L.map(
#                 &quot;map_c9f492ebd6aca582cb8eeb6e3e7a2298&quot;,
#                 {
#                     center: [-3.04207, -60.0061],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d170da863b8e6130b93dede0590cc421 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d170da863b8e6130b93dede0590cc421.addTo(map_c9f492ebd6aca582cb8eeb6e3e7a2298);
#
#
#             ant_path_4c760c4b743ce365e7b8efa11fcaa900 = L.polyline.antPath(
#               [[-3.04207, -60.0061], [-3.04207, -60.0061], [-3.04207, -60.0061], [-3.07992, -60.0022], [-3.04825, -60.0058], [-3.04213, -60.0062], [-3.04288, -60.0035], [-3.08839, -59.9651], [-3.07925, -60.0015], [-3.07928, -60.0014], [-3.13487, -60.0165], [-3.0427, -60.0061], [-3.04263, -60.0071], [-3.04263, -60.0071], [-3.04263, -60.0071], [-3.04263, -60.0071], [-3.04263, -60.0071], [-3.04261, -60.0071], [-3.04264, -60.0071], [-3.04264, -60.0071], [-3.04265, -60.0071], [-3.04265, -60.0071], [-3.08837, -59.9648], [-3.06589, -60.0116], [-3.04272, -60.0071], [-3.0958, -59.9854], [-3.06602, -60.0131], [-3.04264, -60.0071], [-3.12559, -60.0226], [-3.04243, -60.0069], [-3.04832, -59.9978], [-3.04991, -59.9925], [-3.06009, -59.9913], [-3.06055, -59.9912], [-3.06137, -59.9885], [-3.08833, -59.9649], [-3.08837, -59.9649], [-3.08833, -59.9649], [-3.0882, -59.9645], [-3.08806, -59.9633], [-3.08879, -59.9636], [-3.08882, -59.9637], [-3.08882, -59.9638], [-3.08907, -59.9649], [-3.08896, -59.9649], [-3.08848, -59.9648], [-3.08846, -59.9648], [-3.08857, -59.9648], [-3.08839, -59.9648], [-3.08836, -59.9649], [-3.08906, -59.9634], [-3.08882, -59.9649], [-3.08857, -59.9647], [-3.08997, -59.9622], [-3.09198, -59.9638], [-3.09253, -59.9633], [-3.09183, -59.9638], [-3.09991, -59.9747], [-3.04549, -60.0156], [-3.04269, -60.0071], [-3.04269, -60.0071], [-3.04279, -60.0071], [-3.04279, -60.0071], [-3.04261, -60.0071], [-3.04268, -60.0071], [-3.04265, -60.0071], [-3.1264, -60.0206], [-3.00829, -60.0431], [-3.0879, -60.0267], [-3.10836, -60.0267], [-3.1298, -60.0269], [-3.11813, -60.0252], [-3.11043, -60.0344], [-3.10804, -60.0358], [-3.10767, -60.0361], [-3.09207, -60.0528], [-3.08699, -60.0626], [-3.06428, -60.0601], [-3.06065, -60.0629], [-3.0606, -60.0629], [-3.06065, -60.0629], [-3.06064, -60.0629], [-3.06063, -60.0629], [-3.06065, -60.0629], [-3.06063, -60.0629], [-3.06066, -60.0629], [-3.06068, -60.0629], [-3.06068, -60.0629], [-3.06066, -60.0629], [-3.06067, -60.0629], [-3.06067, -60.0629], [-3.06071, -60.0629], [-3.06069, -60.0629], [-3.06069, -60.0629], [-3.06069, -60.0628], [-3.06067, -60.0629], [-3.06071, -60.0629], [-3.06067, -60.0629], [-3.04262, -60.0071], [-3.06585, -60.0034], [-3.0375, -60.0241], [-3.02412, -60.0222], [-2.93023, -60.0056], [-2.88242, -59.9523]],
#               {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;blue&quot;,
#   &quot;weight&quot;: 4,
#   &quot;opacity&quot;: 0.5,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: [
# 10,
# 20,
# ],
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: false,
#   &quot;fillColor&quot;: &quot;blue&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;smoothFactor&quot;: 1.0,
#   &quot;noClip&quot;: false,
#   &quot;paused&quot;: false,
#   &quot;reverse&quot;: false,
#   &quot;hardwareAcceleration&quot;: false,
#   &quot;delay&quot;: 800,
#   &quot;pulseColor&quot;: &quot;#FFFFFF&quot;,
# }
#         ).addTo(map_c9f492ebd6aca582cb8eeb6e3e7a2298);
#
#
#             var marker_498b7a05ebfdda17e25a979d47e25e89 = L.marker(
#                 [-3.07992, -60.0022],
#                 {
# }
#             ).addTo(map_c9f492ebd6aca582cb8eeb6e3e7a2298);
#
#
#             var icon_9df3b855a6e0401c780aedc6f83e84f1 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;signal&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_15b126597f5efc0d9ae
#  User 2
#  Total Handovers: 9
#  Inter-cell: 9
#  Intra-cell: 0
#  Handover Diagnostics:
# • INTER-CELL @ (-3.04255, -60007.00000) at 2023-10-07 01:00:00
#    ↪ CI LTE changed from 235544839.0 to 235570694
#    ⚠ Likely Reason: Low SNR
# • INTER-CELL @ (-3.04260, -60007.00000) at 2023-10-07 01:18:00
#    ↪ CI LTE changed from 235570694.0 to 235544836
#    ⚠ Likely Reason: Normal signal fluctuation
# • INTER-CELL @ (-3.04260, -60007.00000) at 2023-10-07 06:18:00
#    ↪ CI LTE changed from 235544836.0 to 235544833
#    ⚠ Likely Reason: Normal signal fluctuation
# • INTER-CELL @ (-3.09519, -60051.00000) at 2023-11-30 00:52:00
#    ↪ CI LTE changed from 235544833.0 to 82430229
#    ⚠ Likely Reason: Low RSRP, Low SNR
# • INTER-CELL @ (-3.04261, -60007.00000) at 2024-02-06 08:58:00
#    ↪ CI LTE changed from 82430229.0 to 82319627
#    ⚠ Likely Reason: Normal signal fluctuation
# • INTER-CELL @ (-3.08834, -59965.00000) at 2024-02-06 10:32:00
#    ↪ CI LTE changed from 82319627.0 to 82314764
#    ⚠ Likely Reason: Normal signal fluctuation
# • INTER-CELL @ (-3.13406, -60013.00000) at 2024-03-26 11:24:00
#    ↪ CI LTE changed from 82314764.0 to 82322690
#    ⚠ Likely Reason: Low RSRP, Low SNR
# • INTER-CELL @ (-3.12982, -60027.00000) at 2024-04-11 11:49:00
#    ↪ CI LTE changed from 82322690.0 to 235777311
#    ⚠ Likely Reason: Normal signal fluctuation
# • INTER-CELL @ (-3.04262, -60007.00000) at 2024-04-15 13:29:00
#    ↪ CI LTE changed from 235777311.0 to 82319627
#    ⚠ Likely Reason: Normal signal fluctuation
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3166f3917a6daf1b671308ed8bd82e91 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-ant-path@1.1.2/dist/leaflet-ant-path.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3166f3917a6daf1b671308ed8bd82e91&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3166f3917a6daf1b671308ed8bd82e91 = L.map(
#                 &quot;map_3166f3917a6daf1b671308ed8bd82e91&quot;,
#                 {
#                     center: [-3.04208, -60006.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ae28394798d442ab604758502b27c072 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ae28394798d442ab604758502b27c072.addTo(map_3166f3917a6daf1b671308ed8bd82e91);
#
#
#             ant_path_79cd9cce43aaa52e7e3b0890eb4178f1 = L.polyline.antPath(
#               [[-3.04208, -60006.0], [-3.04255, -60007.0], [-3.0426, -60007.0], [-3.0426, -60007.0], [-3.09519, -60051.0], [-3.04261, -60007.0], [-3.08834, -59965.0], [-3.09015, -59966.0], [-3.08909, -59965.0], [-3.13406, -60013.0], [-3.12982, -60027.0], [-3.04262, -60007.0]],
#               {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;blue&quot;,
#   &quot;weight&quot;: 4,
#   &quot;opacity&quot;: 0.5,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: [
# 10,
# 20,
# ],
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: false,
#   &quot;fillColor&quot;: &quot;blue&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;smoothFactor&quot;: 1.0,
#   &quot;noClip&quot;: false,
#   &quot;paused&quot;: false,
#   &quot;reverse&quot;: false,
#   &quot;hardwareAcceleration&quot;: false,
#   &quot;delay&quot;: 800,
#   &quot;pulseColor&quot;: &quot;#FFFFFF&quot;,
# }
#         ).addTo(map_3166f3917a6daf1b671308ed8bd82e91);
#
#
#             var marker_641b1fecf67c834168edc9ccfb9cdc33 = L.marker(
#                 [-3.04255, -60007.0],
#                 {
# }
#             ).addTo(map_3166f3917a6daf1b671308ed8bd82e91);
#
#
#             var icon_560141bd72572d608c09e5b1066defb4 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;signal&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_3cdb69cb21acdbe17f7c5fc70e430224 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c654d514cdf14148517eed74341e96dd = $(`&lt;div id=&quot;html_c654d514cdf14148517eed74341e96dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;INTER-CELL Handover&lt;br&gt;Time: 2023-10-07 01:00:00&lt;br&gt;CI: 235570694 | PCI: 410&lt;br&gt;Reason: Low SNR&lt;/div&gt;`)[0];
#                 popup_3cdb69cb21acdbe17f7c5fc70e430224.setContent(html_c654d514cdf14148517eed74341e96dd);
#
#
#
#         marker_641b1fecf67c834168edc9ccfb9cdc33.bindPopup(popup_3cdb69cb21acdbe17f7c5fc70e430224)
#         ;
#
#
#
#
#                 marker_641b1fecf67c834168edc9ccfb9cdc33.setIcon(icon_560141bd72572d608c09e5b1066defb4);
#
#
#             var marker_9e81ab876aa43faddb056795c2c08ad7 = L.marker(
#                 [-3.0426, -60007.0],
#                 {
# }
#             ).addTo(map_3166f3917a6daf1b671308ed8bd82e91);
#
#
#             var icon_fa70a656cae1fa1c18d629c8f0b94658 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;signal&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_a643333828872957a4249416b41f437f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2db9e4781c0499acb2709197066001e6 = $(`&lt;div id=&quot;html_2db9e4781c0499acb2709197066001e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;INTER-CELL Handover&lt;br&gt;Time: 2023-10-07 01:18:00&lt;br&gt;CI: 235544836 | PCI: 87&lt;br&gt;Reason: Normal signal fluctuation&lt;/div&gt;`)[0];
#                 popup_a643333828872957a4249416b41f437f.setContent(html_2db9e4781c0499acb2709197066001e6);
#
#
#
#         marker_9e81ab876aa43faddb056795c2c08ad7.bindPopup(popup_a643333828872957a4249416b41f437f)
